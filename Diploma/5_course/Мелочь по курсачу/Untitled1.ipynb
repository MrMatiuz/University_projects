# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
file = open('mesh.dat')
size = file.readline().split()
coords = file.readlines()

# %%
x = [float(c.split()[0]) for c in coords]
y = [float(c.split()[1]) for c in coords]

# %%
plt.rcParams["figure.figsize"] = (20,15)
plt.scatter(x, y, marker='o')
plt.plot([x[65*76]]*10, np.arange(0,1,0.1), c='r')
plt.show()

# %%
x = np.array(x)

# %%
len(x)
# Out:
# 8385

# %%
len(np.unique(x))
# Out:
# 8253

# %%
size
# Out:
# ['132', '68']

# %%
np.arange(0,1,0.1)
# Out:
# array([0])

# %%
str_a = '''
1.341919e-20
5.444470e-03
2.019389e-02
4.082290e-02
6.270981e-02
7.924852e-02
8.295734e-02
6.551425e-02
2.103783e-02
5.344530e-02
1.583656e-01
3.104661e-01
4.839126e-01
6.580486e-01
8.289109e-01
9.781511e-01
1.100217e+00
1.181237e+00
1.225508e+00
1.184350e+00
1.100124e+00
6.552533e-01
5.627864e-02
4.755664e-01
1.107310e+00
1.730876e+00
2.479212e+00
4.126526e+00
1.013191e+01
1.301276e+01
5.775938e+00
2.147595e+00
7.680926e-01
2.421792e-01
5.515056e-02
1.729612e-02
6.895476e-03
1.550605e-03
1.453467e-03
1.052910e-03
6.876038e-04
2.768114e-04
6.314267e-04
8.862027e-04
3.326106e-04
3.465551e-04
9.040019e-04
1.852021e-03
2.373178e-03
4.942735e-03
5.922618e-03
9.320820e-03
8.460325e-03
2.219512e-02
9.599054e-03
3.231097e-03
5.144465e-04
1.581136e-03
8.354223e-04
5.030948e-04
8.981401e-04
1.295267e-04
6.888924e-04
2.401572e-04
'''

# %%
list_of_col = [col_73,
               col_74,
               col_75,
               col_76,
               col_77,
               col_78]

# %%
for num, col in enumerate(list_of_col):
#     plt.plot(col, 'o')
    plt.plot(col, label=num+73)
    plt.legend()
plt.show()

# %%
col_ = list_a

# %%
col_73
col_74
col_75
col_76
col_77
col_78

# %%
# list_a = [float(a) for a in str_a.split()]

plt.plot(col_76, color='g')
plt.plot(col_76, 'o', color='g')
plt.plot(33, col_76[33], 'o', color='r')
plt.show()

# %%
col_76[33]
# Out:
# 1.111225
